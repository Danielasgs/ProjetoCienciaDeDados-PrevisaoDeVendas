# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Nosso desafio é conseguir prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa Hashtag investe: TV, Jornal e Rádio
#
# - Base de Dados: https://drive.google.com/drive/folders/1o2lpxoi9heyQV1hIlsHXWSfDkBPtze-V?usp=sharing

# %% [markdown]
# ### Passo a Passo de um Projeto de Ciência de Dados
#
# - Passo 1: Entendimento do Desafio
# - Passo 2: Entendimento da Área/Empresa
# - Passo 3: Extração/Obtenção de Dados
# - Passo 4: Ajuste de Dados (Tratamento/Limpeza)
# - Passo 5: Análise Exploratória
# - Passo 6: Modelagem + Algoritmos (Aqui que entra a Inteligência Artificial, se necessário)
# - Passo 7: Interpretação de Resultados

# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Nosso desafio é conseguir prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa Hashtag investe: TV, Jornal e Rádio
# - TV, Jornal e Rádio estão em milhares de reais
# - Vendas estão em milhões

# %% [markdown]
# #### Importar a Base de dados

# %%
import pandas as pd

tabela = pd.read_csv('advertising.csv')
display(tabela)
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2   45.9    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]

# %%
print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Radio   200 non-null    float64
#  2   Jornal  200 non-null    float64
#  3   Vendas  200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB
# None

# %%
#!pip install matplotlib -> graficos
#!pip install seaborn -> graficos
#!pip install scikit-learn -> Inteligencia artificial

# %% [markdown]
# #### Análise Exploratória
# - Vamos tentar visualizar como as informações de cada item estão distribuídas
# - Vamos ver a correlação entre cada um dos itens

# %%
import matplotlib.pyplot as plt
import seaborn as sns

display(tabela.corr())

# criar o gráfico
sns.heatmap(tabela.corr(), cmap='Wistia', annot=True)
# exibir o grafico
plt.show()
# Out:
#               TV     Radio    Jornal    Vendas
# TV      1.000000  0.054809  0.056648  0.901208
# Radio   0.054809  1.000000  0.354104  0.349631
# Jornal  0.056648  0.354104  1.000000  0.157960
# Vendas  0.901208  0.349631  0.157960  1.000000

# %% [markdown]
# #### Com isso, podemos partir para a preparação dos dados para treinarmos o Modelo de Machine Learning
#
# - Separando em dados de treino e dados de teste

# %%
# y -> quem prever (vendas)
# x -> usados para previsão (todos os outros)

y = tabela['Vendas']
x = tabela[['TV', 'Radio', 'Jornal']]

from sklearn.model_selection import train_test_split

xTreino, xTeste, yTreino, yTeste = train_test_split(x, y, test_size=0.3, random_state=1)

# %% [markdown]
# #### Temos um problema de regressão - Vamos escolher os modelos que vamos usar:
#
# - Regressão Linear
# - RandomForest (Árvore de Decisão)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

#criar
modeloLinear = LinearRegression()
modeloArvoreDecisao = RandomForestRegressor()

#treinar
modeloLinear.fit(xTreino, yTreino)
modeloArvoreDecisao.fit(xTreino, yTreino)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### Teste da AI e Avaliação do Melhor Modelo
#
# - Vamos usar o R² -> diz o % que o nosso modelo consegue explicar o que acontece

# %%
# fazer previsão dos testes

previsaoLinear = modeloLinear.predict(xTeste)
previsaoArvoreDecisao = modeloArvoreDecisao.predict(xTeste)

from sklearn.metrics import r2_score

print(r2_score(yTeste, previsaoLinear))
print(r2_score(yTeste, previsaoArvoreDecisao))
# Out:
# 0.9071151423684273
# 0.966388230285094

# %% [markdown]
# #### Visualização Gráfica das Previsões

# %%
tabelaAuxiliar = pd.DataFrame()
tabelaAuxiliar['y Teste'] = yTeste
tabelaAuxiliar['Árvore de decisão'] = previsaoArvoreDecisao
tabelaAuxiliar['Linear'] = previsaoLinear

plt.figure(figsize=(15, 6))
sns.lineplot(data=tabelaAuxiliar)
plt.show()

# %% [markdown]
# #### Como fazer uma nova previsão?

# %%
# O melhor modelo nesse caso é a arvore de decisão

novos = pd.read_csv('novos.csv')
display(novos)
# Out:
#       TV  Radio  Jornal
# 0   23.1    3.8    69.2
# 1   44.5    0.0     5.1
# 2  170.2   45.9     0.0

# %%
print(modeloArvoreDecisao.predict(novos))
# Out:
# [ 7.424  8.567 19.941]
